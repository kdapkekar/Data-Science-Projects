# %% [markdown]
# # Introduction to Numpy and Pandas

# %%
import pandas as pd

# %%
df = pd.read_csv("bitcoin_dataset.csv")
df = df.fillna(df.mean())

# %% [markdown]
# # Data Collection

# %%
print(df.iloc[1023])
# Out:
# Date                                                     12/6/2012
# btc_market_price                                           13.6888
# btc_total_bitcoins                                     1.05288e+07
# btc_market_cap                                         1.44126e+08
# btc_trade_volume                                            718984
# btc_blocks_size                                               3829
# btc_avg_block_size                                        0.127314
# btc_n_orphaned_blocks                                            0
# btc_n_transactions_per_block                                   250
# btc_median_confirmation_time                                  11.6
# btc_hash_rate                                              24.4457
# btc_difficulty                                         3.43891e+06
# btc_miners_revenue                                         49361.8
# btc_transaction_fees                                       31.0582
# ...

# %%
df.iloc[1023]
# Out:
# Date                                                     12/6/2012
# btc_market_price                                           13.6888
# btc_total_bitcoins                                     1.05288e+07
# btc_market_cap                                         1.44126e+08
# btc_trade_volume                                            718984
# btc_blocks_size                                               3829
# btc_avg_block_size                                        0.127314
# btc_n_orphaned_blocks                                            0
# btc_n_transactions_per_block                                   250
# btc_median_confirmation_time                                  11.6
# btc_hash_rate                                              24.4457
# btc_difficulty                                         3.43891e+06
# btc_miners_revenue                                         49361.8
# btc_transaction_fees                                       31.0582
# ...

# %% [markdown]
# # Exploratory Data Analysis

# %%
import seaborn as sns 
import matplotlib.pyplot as plt 
import scipy.stats as stats
from scipy.stats import pearsonr
from warnings import filterwarnings
filterwarnings('ignore')

# %%
p = sns.jointplot( data = df,x = "btc_market_price", y = "btc_market_price", kind = 'reg')
plt.show()
stats.pearsonr(df['btc_market_price'], df['btc_market_price'])
# Out:
# (1.0, 0.0)

# %%
p = sns.jointplot( data = df,x = "btc_market_cap", y = "btc_market_price", kind = 'reg')
plt.show()
stats.pearsonr(df['btc_market_cap'], df['btc_market_price'])
# Out:
# (0.9997826765218778, 0.0)

# %%
p = sns.jointplot( data = df,x = "btc_total_bitcoins", y = "btc_market_price", kind = 'reg')
plt.show()
stats.pearsonr(df['btc_total_bitcoins'], df['btc_market_price'])
# Out:
# (0.3922339090142384, 1.704175763115078e-107)

# %%
p = sns.jointplot( data = df,x = "btc_trade_volume", y = "btc_market_price", kind = 'reg')
plt.show()
stats.pearsonr(df['btc_trade_volume'], df['btc_market_price'])
# Out:
# (0.8686075377272551, 0.0)

# %%
p = sns.jointplot( data = df,x = "btc_blocks_size", y = "btc_market_price", kind = 'reg')
plt.show()
stats.pearsonr(df['btc_blocks_size'], df['btc_market_price'])
# Out:
# (0.6740588562568346, 0.0)

# %%
p = sns.jointplot( data = df,x = "btc_avg_block_size", y = "btc_market_price", kind = 'reg')
plt.show()
stats.pearsonr(df['btc_avg_block_size'], df['btc_market_price'])
# Out:
# (0.5440325252675923, 1.3663233539672172e-223)

# %%
p = sns.jointplot( data = df,x = "btc_n_orphaned_blocks", y = "btc_market_price", kind = 'reg')
plt.show()
stats.pearsonr(df['btc_n_orphaned_blocks'], df['btc_market_price'])
# Out:
# (-0.07639999339315412, 3.743366863806207e-05)

# %%
p = sns.jointplot( data = df,x = "btc_n_transactions_per_block", y = "btc_market_price", kind = 'reg')
plt.show()
stats.pearsonr(df['btc_n_transactions_per_block'], df['btc_market_price'])
# Out:
# (0.5441247005124086, 1.1107960899532568e-223)

# %%
p = sns.jointplot( data = df,x = "btc_median_confirmation_time", y = "btc_market_price", kind = 'reg')
plt.show()
stats.pearsonr(df['btc_median_confirmation_time'], df['btc_market_price'])
# Out:
# (0.27408004446675077, 3.0674519359215384e-51)

# %%
p = sns.jointplot( data = df,x = "btc_hash_rate", y = "btc_market_price", kind = 'reg')
plt.show()
stats.pearsonr(df['btc_hash_rate'], df['btc_market_price'])
# Out:
# (0.9208760210000024, 0.0)

# %%
p = sns.jointplot( data = df,x = "btc_difficulty", y = "btc_market_price", kind = 'reg')
plt.show()
stats.pearsonr(df['btc_difficulty'], df['btc_market_price'])
# Out:
# (0.9169129774377394, 0.0)

# %%
p = sns.jointplot( data = df,x = "btc_miners_revenue", y = "btc_market_price", kind = 'reg')
plt.show()
stats.pearsonr(df['btc_miners_revenue'], df['btc_market_price'])
# Out:
# (0.9867320856324151, 0.0)

# %%
p = sns.jointplot( data = df,x = "btc_transaction_fees", y = "btc_market_price", kind = 'reg')
plt.show()
stats.pearsonr(df['btc_transaction_fees'], df['btc_market_price'])
# Out:
# (0.8065676796632089, 0.0)

# %%
p = sns.jointplot( data = df,x = "btc_cost_per_transaction_percent", y = "btc_market_price", kind = 'reg')
plt.show()
stats.pearsonr(df['btc_cost_per_transaction_percent'], df['btc_market_price'])
# Out:
# (-0.013517293631854553, 0.466368178672829)

# %%
p = sns.jointplot( data = df,x = "btc_cost_per_transaction", y = "btc_market_price", kind = 'reg')
plt.show()
stats.pearsonr(df['btc_cost_per_transaction'], df['btc_market_price'])
# Out:
# (0.8155073414716751, 0.0)

# %%
p = sns.jointplot( data = df,x = "btc_n_unique_addresses", y = "btc_market_price", kind = 'reg')
plt.show()
stats.pearsonr(df['btc_n_unique_addresses'], df['btc_market_price'])
# Out:
# (0.6639174028794768, 0.0)

# %%
p = sns.jointplot( data = df,x = "btc_n_transactions", y = "btc_market_price", kind = 'reg')
plt.show()
stats.pearsonr(df['btc_n_transactions'], df['btc_market_price'])
# Out:
# (0.5696027129379863, 1.201643678532597e-249)

# %%
p = sns.jointplot( data = df,x = "btc_n_transactions_total", y = "btc_market_price", kind = 'reg')
plt.show()
stats.pearsonr(df['btc_n_transactions_total'], df['btc_market_price'])
# Out:
# (0.6800478813410609, 0.0)

# %%
p = sns.jointplot( data = df,x = "btc_n_transactions_excluding_popular", y = "btc_market_price", kind = 'reg')
plt.show()
stats.pearsonr(df['btc_n_transactions_excluding_popular'], df['btc_market_price'])
# Out:
# (0.558416046720704, 5.737435637635552e-238)

# %%
p = sns.jointplot( data = df,x = "btc_n_transactions_excluding_chains_longer_than_100", y = "btc_market_price", kind = 'reg')
plt.show()
stats.pearsonr(df['btc_n_transactions_excluding_chains_longer_than_100'], df['btc_market_price'])
# Out:
# (0.5672811999602522, 3.470522799867536e-247)

# %%
p = sns.jointplot( data = df,x = "btc_output_volume", y = "btc_market_price", kind = 'reg')
plt.show()
stats.pearsonr(df['btc_output_volume'], df['btc_market_price'])
# Out:
# (0.11173404047261982, 1.5448507491012516e-09)

# %%
p = sns.jointplot( data = df,x = "btc_estimated_transaction_volume", y = "btc_market_price", kind = 'reg')
plt.show()
stats.pearsonr(df['btc_estimated_transaction_volume'], df['btc_market_price'])
# Out:
# (0.05089376533949091, 0.006066875403947132)

# %%
p = sns.jointplot( data = df,x = "btc_estimated_transaction_volume_usd", y = "btc_market_price", kind = 'reg')
plt.show()
stats.pearsonr(df['btc_estimated_transaction_volume_usd'], df['btc_market_price'])
# Out:
# (0.9683077328629317, 0.0)

# %% [markdown]
# # Data Cleaning

# %%
'btc_market_cap', 'btc_n_transactions','btc_miners_revenue','btc_cost_per_transaction','btc_difficulty','btc_hash_rate','btc_cost_per_transaction_percent'
# Out:
# ('btc_market_cap',
#  'btc_n_transactions',
#  'btc_miners_revenue',
#  'btc_cost_per_transaction',
#  'btc_difficulty',
#  'btc_hash_rate',
#  'btc_cost_per_transaction_percent')

# %%
Columns = ['Date','btc_market_price','btc_total_bitcoins','btc_trade_volume','btc_blocks_size','btc_avg_block_size','btc_n_orphaned_blocks','btc_n_transactions_per_block','btc_median_confirmation_time','btc_transaction_fees','btc_n_unique_addresses','btc_n_transactions_total','btc_n_transactions_excluding_popular','btc_n_transactions_excluding_chains_longer_than_100','btc_output_volume','btc_estimated_transaction_volume','btc_estimated_transaction_volume_usd']
df1 = df.drop(Columns,axis=1)

# %%
df1.isnull().sum(axis=0)
# Out:
# btc_market_cap                      0
# btc_hash_rate                       0
# btc_difficulty                      0
# btc_miners_revenue                  0
# btc_cost_per_transaction_percent    0
# btc_cost_per_transaction            0
# btc_n_transactions                  0
# dtype: int64

# %% [markdown]
# # Model Formulation and Predictions

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
X_train, X_test, y_train, y_test = train_test_split(df1,df['btc_market_price'],test_size = 0.3,random_state=42)

# %%
Lreg = LinearRegression()

# %%
Lreg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
pred = Lreg.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt

# %%
rmse = sqrt(mean_squared_error(y_test,pred))

# %%
print(rmse)
# Out:
# 21.156774409473186
